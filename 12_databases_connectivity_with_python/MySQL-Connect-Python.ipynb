# %%
import pandas as pd

# %%
from sqlalchemy import create_engine,text
import mysql.connector

# %%
user = 'mention user name'
password = 'type password'
host = 'mention host name'
port = 'mention port number'
database = 'mention database name'

connection_string = f"mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database}"

engine = create_engine(connection_string)

connection = engine.connect()

# %%
with engine.connect() as conn:
    res = conn.execute(text("select * from dummy1 where city = 'Lyon' "))
    for row in res:
        print(row)
# Out:
# (5, 'Zoe', 'Ashley', 'Female', 'Zoe_Ashley4146@ds59r.autos', '5-772-412-5541', 'Lyon')
# (214, 'Maggie', 'Rees', 'Female', 'Maggie_Rees4482@hepmv.info', '7-835-722-0067', 'Lyon')
# (307, 'Hank', 'Healy', 'Male', 'Hank_Healy6098@bu2lo.directory', '4-004-166-4448', 'Lyon')
# (537, 'Carl', 'Stewart', 'Male', 'Carl_Stewart4981@jh02o.software', '4-823-113-7223', 'Lyon')
# (574, 'Rylee', 'Dunbar', 'Female', 'Rylee_Dunbar6412@ckzyi.pro', '2-805-640-0620', 'Lyon')
# (925, 'Bart', 'Avery', 'Male', 'Bart_Avery4534@crzq7.design', '1-284-702-3203', 'Lyon')
# (1180, 'Nathan', 'Abbey', 'Male', 'Nathan_Abbey2336@urn0m.club', '1-762-407-2737', 'Lyon')
# (1458, 'Alexander', 'Vass', 'Male', 'Alexander_Vass8373@evyvh.store', '0-603-284-3001', 'Lyon')
# (1566, 'Nick', 'Notman', 'Male', 'Nick_Notman7394@p5emz.services', '7-105-105-8827', 'Lyon')
# (1622, 'Chester', 'Mcgee', 'Male', 'Chester_Mcgee3269@jh02o.property', '1-745-784-3334', 'Lyon')
# ...

# %%
# %load_ext sql

# %%
# %sql $connection_string

# %%
# %%sql
#
# select * from dummy1
# Out:
#  * mysql+mysqlconnector://root:***@127.0.0.1:3306/sql_prac
# 7438 rows affected.
# [(1, 'Rachael', 'Lowe', 'Female', 'Rachael_Lowe3396@xtwt3.net', '3-664-210-3648', 'Phoenix'),
#  (2, 'Hope', 'Isaac', 'Female', 'Hope_Isaac4146@yafr7.site', '0-425-114-3712', 'Escondido'),
#  (3, 'Penelope', 'Harrington', 'Female', 'Penelope_Harrington9070@chkzl.digital', '6-538-572-7014', 'Scottsdale'),
#  (4, 'Alexander', 'Whittle', 'Male', 'Alexander_Whittle2209@voylg.design', '4-377-113-1450', 'London'),
#  (5, 'Zoe', 'Ashley', 'Female', 'Zoe_Ashley4146@ds59r.autos', '5-772-412-5541', 'Lyon'),
#  (6, 'Emmanuelle', 'Whatson', 'Female', 'Emmanuelle_Whatson6431@bcfhs.meet', '2-616-728-7143', 'San Francisco'),
#  (7, 'Alessia', 'Paterson', 'Female', 'Alessia_Paterson2817@fhuux.design', '2-675-763-5145', 'Milwaukee'),
#  (8, 'Camila', 'Wilde', 'Female', 'Camila_Wilde8637@xqj6f.us', '0-043-101-0252', 'Minneapolis'),
# ...

# %%
pd.read_sql("dummy1",connection)
# Out:
#         Id  Firstname    Lastname  Gender
# 0        1    Rachael        Lowe  Female  \
# 1        2       Hope       Isaac  Female
# 2        3   Penelope  Harrington  Female
# 3        4  Alexander     Whittle    Male
# 4        5        Zoe      Ashley  Female
# ...    ...        ...         ...     ...
# 7433  7434       Erin      Knight  Female
# 7434  7435    Candice   Goldsmith  Female
# 7435  7436      Bryon      Squire    Male
# 7436  7437    Gabriel       Quinn    Male
# 7437  7438      Rufus      Baxter    Male
#
#                                       Email         Contact            City
# 0                Rachael_Lowe3396@xtwt3.net  3-664-210-3648         Phoenix
# 1                 Hope_Isaac4146@yafr7.site  0-425-114-3712       Escondido
# 2     Penelope_Harrington9070@chkzl.digital  6-538-572-7014      Scottsdale
# 3        Alexander_Whittle2209@voylg.design  4-377-113-1450          London
# ...

# %%
pd.read_sql("select * from dummy1",connection)
# Out:
#         Id  Firstname    Lastname  Gender
# 0        1    Rachael        Lowe  Female  \
# 1        2       Hope       Isaac  Female
# 2        3   Penelope  Harrington  Female
# 3        4  Alexander     Whittle    Male
# 4        5        Zoe      Ashley  Female
# ...    ...        ...         ...     ...
# 7433  7434       Erin      Knight  Female
# 7434  7435    Candice   Goldsmith  Female
# 7435  7436      Bryon      Squire    Male
# 7436  7437    Gabriel       Quinn    Male
# 7437  7438      Rufus      Baxter    Male
#
#                                       Email         Contact            City
# 0                Rachael_Lowe3396@xtwt3.net  3-664-210-3648         Phoenix
# 1                 Hope_Isaac4146@yafr7.site  0-425-114-3712       Escondido
# 2     Penelope_Harrington9070@chkzl.digital  6-538-572-7014      Scottsdale
# 3        Alexander_Whittle2209@voylg.design  4-377-113-1450          London
# ...

# %%
pd.read_sql_query("select * from dummy1",connection)
# Out:
#         Id  Firstname    Lastname  Gender
# 0        1    Rachael        Lowe  Female  \
# 1        2       Hope       Isaac  Female
# 2        3   Penelope  Harrington  Female
# 3        4  Alexander     Whittle    Male
# 4        5        Zoe      Ashley  Female
# ...    ...        ...         ...     ...
# 7433  7434       Erin      Knight  Female
# 7434  7435    Candice   Goldsmith  Female
# 7435  7436      Bryon      Squire    Male
# 7436  7437    Gabriel       Quinn    Male
# 7437  7438      Rufus      Baxter    Male
#
#                                       Email         Contact            City
# 0                Rachael_Lowe3396@xtwt3.net  3-664-210-3648         Phoenix
# 1                 Hope_Isaac4146@yafr7.site  0-425-114-3712       Escondido
# 2     Penelope_Harrington9070@chkzl.digital  6-538-572-7014      Scottsdale
# 3        Alexander_Whittle2209@voylg.design  4-377-113-1450          London
# ...

# %%
pd.read_sql_table("dummy1",connection)
# Out:
#         Id  Firstname    Lastname  Gender
# 0        1    Rachael        Lowe  Female  \
# 1        2       Hope       Isaac  Female
# 2        3   Penelope  Harrington  Female
# 3        4  Alexander     Whittle    Male
# 4        5        Zoe      Ashley  Female
# ...    ...        ...         ...     ...
# 7433  7434       Erin      Knight  Female
# 7434  7435    Candice   Goldsmith  Female
# 7435  7436      Bryon      Squire    Male
# 7436  7437    Gabriel       Quinn    Male
# 7437  7438      Rufus      Baxter    Male
#
#                                       Email         Contact            City
# 0                Rachael_Lowe3396@xtwt3.net  3-664-210-3648         Phoenix
# 1                 Hope_Isaac4146@yafr7.site  0-425-114-3712       Escondido
# 2     Penelope_Harrington9070@chkzl.digital  6-538-572-7014      Scottsdale
# 3        Alexander_Whittle2209@voylg.design  4-377-113-1450          London
# ...

# %%
df = pd.read_sql_query("select * from dummy1 where city = 'Tokyo'",connection)

# %%
df
# Out:
#       Id Firstname Lastname  Gender                             Email
# 0      9     Ciara   Radley  Female          Ciara_Radley104@hepmv.us  \
# 1     95  Michelle    Knott  Female    Michelle_Knott9291@ds59r.audio
# 2    124     Bryon    Brett    Male         Bryon_Brett1254@bqkv0.org
# 3    126   Katelyn   Walton  Female   Katelyn_Walton929@gnjps.website
# 4    127     Denis    Poole    Male       Denis_Poole3871@v1wn5.autos
# ..   ...       ...      ...     ...                               ...
# 74  6566   Jessica    Snell  Female  Jessica_Snell9193@ohqqh.catering
# 75  6702   Cherish   Ingram  Female     Cherish_Ingram6321@zynuu.info
# 76  6705   Adalind   Bryant  Female  Adalind_Bryant1336@bqkv0.digital
# 77  7101   Christy    Allen  Female      Christy_Allen8243@bqkv0.info
# 78  7295   Phillip   Wright    Male    Phillip_Wright5777@qu9ml.media
#
#            Contact   City
# 0   2-836-724-4571  Tokyo
# 1   2-575-532-5174  Tokyo
# 2   2-240-340-5855  Tokyo
# ...

# %%
df.to_sql(name='dummy1_tokyo', con=connection, if_exists='replace', index=False)
# Out:
# 79

# %%
connection.commit()

# %%
connection.close()
