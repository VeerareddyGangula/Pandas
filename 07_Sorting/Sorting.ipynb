# %%
"""
topics covered in this notebook

sort_values()
sort_index()
nlargest()
nsmallest

"""

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\gangu\Desktop\Tech\pandas\data\survey\survey_results_public.csv",index_col='ResponseId')

schema_df = pd.read_csv(r"C:\Users\gangu\Desktop\Tech\pandas\data\survey\survey_results_schema.csv",index_col='qname')

# %%
pd.set_option('display.max_columns',79)
pd.set_option('display.max_rows',79)

# %%
df.head()
# Out:
#                                                    MainBranch
# ResponseId
# 1                                               None of these  \
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork
# ResponseId
# 1                           NaN                                   NaN  \
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities
# ResponseId
# 1                                                NaN  \
# ...

# %%
df.sort_values(by=['Country','ConvertedCompYearly'],ascending=[True,False],inplace=True)

# %%
df[['Country','ConvertedCompYearly']].head(50)
# Out:
#                 Country  ConvertedCompYearly
# ResponseId
# 38513       Afghanistan             158484.0
# 43640       Afghanistan              92448.0
# 6892        Afghanistan              15600.0
# 43691       Afghanistan              13212.0
# 2449        Afghanistan              10894.0
# 6243        Afghanistan               5280.0
# 23224       Afghanistan               5280.0
# 55666       Afghanistan               2400.0
# 49274       Afghanistan               1634.0
# 1960        Afghanistan                  NaN
# 2738        Afghanistan                  NaN
# 3642        Afghanistan                  NaN
# 3776        Afghanistan                  NaN
# 3887        Afghanistan                  NaN
# 4503        Afghanistan                  NaN
# 5465        Afghanistan                  NaN
# 6777        Afghanistan                  NaN
# 7945        Afghanistan                  NaN
# 8891        Afghanistan                  NaN
# 10234       Afghanistan                  NaN
# ...

# %%
df['ConvertedCompYearly'].nlargest(10)
# Out:
# ResponseId
# 40305    50000000.0
# 202      44790396.0
# 62027    35000000.0
# 70523    32500000.0
# 61044    28853768.0
# 18923    22500000.0
# 62224    22500000.0
# 66496    18000000.0
# 1291     15000000.0
# 24164    15000000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df.nlargest(10,columns= 'ConvertedCompYearly')
# Out:
#                                 MainBranch
# ResponseId
# 40305       I am a developer by profession  \
# 202         I am a developer by profession
# 62027       I am a developer by profession
# 70523       I am a developer by profession
# 61044       I am a developer by profession
# 18923       I am a developer by profession
# 62224       I am a developer by profession
# 66496       I am a developer by profession
# 1291        I am a developer by profession
# 24164       I am a developer by profession
#
#                                                    Employment
# ResponseId
# 40305       Independent contractor, freelancer, or self-em...  \
# 202                                       Employed, full-time
# 62027                                     Employed, full-time
# 70523       Independent contractor, freelancer, or self-em...
# 61044                                     I prefer not to say
# 18923                                     Employed, full-time
# ...

# %%
df['ConvertedCompYearly'].nsmallest(10)
# Out:
# ResponseId
# 19913    1.0
# 39916    1.0
# 65743    1.0
# 64367    1.0
# 52006    1.0
# 36436    3.0
# 6124     3.0
# 32333    3.0
# 2377     4.0
# 27981    4.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df.nsmallest(10,columns='ConvertedCompYearly')
# Out:
#                                                    MainBranch
# ResponseId
# 19913       I am not primarily a developer, but I write co...  \
# 39916                          I am a developer by profession
# 65743                          I am a developer by profession
# 64367       I am not primarily a developer, but I write co...
# 52006                          I am a developer by profession
# 36436                          I am a developer by profession
# 6124                           I am a developer by profession
# 32333                          I am a developer by profession
# 2377                           I am a developer by profession
# 27981                          I am a developer by profession
#
#                                                    Employment
# ResponseId
# 19913                                     I prefer not to say  \
# 39916       Employed, full-time;Independent contractor, fr...
# 65743                                     Employed, full-time
# ...
