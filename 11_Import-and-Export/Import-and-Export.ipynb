# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\gangu\Desktop\Tech\pandas\data\survey\survey_results_public.csv",index_col='ResponseId')

schema_df = pd.read_csv(r"C:\Users\gangu\Desktop\Tech\pandas\data\survey\survey_results_schema.csv",index_col='qname')

# %%
df
# Out:
#                                                    MainBranch
# ResponseId
# 1                                               None of these  \
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment
# ResponseId
# 1                                                         NaN  \
# 2                                         Employed, full-time
# ...

# %%
df.query('Country == "India" ')
# Out:
#                                                    MainBranch
# ResponseId
# 7                                 I code primarily as a hobby  \
# 8                              I am a developer by profession
# 66                             I am a developer by profession
# 141                            I am a developer by profession
# 152                            I am a developer by profession
# ...                                                       ...
# 73185                          I am a developer by profession
# 73194       I used to be a developer by profession, but no...
# 73256                          I am a developer by profession
# 73258                                   I am learning to code
# 73259                          I am a developer by profession
#
#                                     Employment
# ResponseId
# 7                           Student, part-time  \
# 8           Not employed, but looking for work
# 66                         Employed, full-time
# ...

# %%
India_df = df.query('Country == "India" ')

# %%
India_df
# Out:
#                                                    MainBranch
# ResponseId
# 7                                 I code primarily as a hobby  \
# 8                              I am a developer by profession
# 66                             I am a developer by profession
# 141                            I am a developer by profession
# 152                            I am a developer by profession
# ...                                                       ...
# 73185                          I am a developer by profession
# 73194       I used to be a developer by profession, but no...
# 73256                          I am a developer by profession
# 73258                                   I am learning to code
# 73259                          I am a developer by profession
#
#                                     Employment
# ResponseId
# 7                           Student, part-time  \
# 8           Not employed, but looking for work
# 66                         Employed, full-time
# ...

# %%
from sqlalchemy import create_engine,text

Database_Con = f'mssql://@{Server}/{Database}?driver={Driver}'

engine = create_engine(Database_Con)

# %%
with engine.connect() as con:
    result = con.execute(text("select * from geo"))

    df1 = pd.DataFrame(result)

# %%
df1
# Out:
#   GeoID          Geo    Region
# 0    G1        India      APAC
# 1    G2          USA  Americas
# 2    G3       Canada  Americas
# 3    G4  New Zealand      APAC
# 4    G5    Australia      APAC
# 5    G6           UK    Europe

# %% [markdown]
# read_sql

# %%
query = "select * from geo"

pd.read_sql(text(query),con=engine.connect())
# Out:
#   GeoID          Geo    Region
# 0    G1        India      APAC
# 1    G2          USA  Americas
# 2    G3       Canada  Americas
# 3    G4  New Zealand      APAC
# 4    G5    Australia      APAC
# 5    G6           UK    Europe

# %%
pd.read_sql("geo",con = engine.connect())
# Out:
#   GeoID          Geo    Region
# 0    G1        India      APAC
# 1    G2          USA  Americas
# 2    G3       Canada  Americas
# 3    G4  New Zealand      APAC
# 4    G5    Australia      APAC
# 5    G6           UK    Europe

# %% [markdown]
# read_sql_query

# %%
query = "select * from geo"

pd.read_sql_query(text(query),con=engine.connect())
# Out:
#   GeoID          Geo    Region
# 0    G1        India      APAC
# 1    G2          USA  Americas
# 2    G3       Canada  Americas
# 3    G4  New Zealand      APAC
# 4    G5    Australia      APAC
# 5    G6           UK    Europe

# %% [markdown]
# read_sql_table

# %%
pd.read_sql_table("geo",con = engine.connect())
# Out:
#   GeoID          Geo    Region
# 0    G1        India      APAC
# 1    G2          USA  Americas
# 2    G3       Canada  Americas
# 3    G4  New Zealand      APAC
# 4    G5    Australia      APAC
# 5    G6           UK    Europe

# %% [markdown]
# to_sql

# %%
India_df.to_sql("survey_india",con=engine.connect(),if_exists='replace',index=False)
# Out:
# 9

# %%
pd.read_sql("survey_india",con=engine.connect())
# Out:
#                                              MainBranch
# 0                           I code primarily as a hobby  \
# 1                        I am a developer by profession
# 2                        I am a developer by profession
# 3                        I am a developer by profession
# 4                        I am a developer by profession
# ...                                                 ...
# 6634                     I am a developer by profession
# 6635  I used to be a developer by profession, but no...
# 6636                     I am a developer by profession
# 6637                              I am learning to code
# 6638                     I am a developer by profession
#
#                               Employment
# 0                     Student, part-time  \
# 1     Not employed, but looking for work
# 2                    Employed, full-time
# 3                    Employed, full-time
# 4                    Employed, full-time
# ...
