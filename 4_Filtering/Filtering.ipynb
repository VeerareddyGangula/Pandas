# %%
"""
topics covered in this notebook

str.contains

str[]

str.len()

str.startswith()

str.endswith()



"""

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\gangu\Desktop\Tech\pandas\data\survey\survey_results_public.csv',index_col='ResponseId')

schema_df = pd.read_csv(r'C:\Users\gangu\Desktop\Tech\pandas\data\survey\survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 79)
pd.set_option('display.max_rows', 79)

# %%
df.head()
# Out:
#                                                    MainBranch
# ResponseId
# 1                                               None of these  \
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork
# ResponseId
# 1                           NaN                                   NaN  \
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities
# ResponseId
# 1                                                NaN  \
# ...

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
filt
# Out:
# ResponseId
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 73264     True
# 73265     True
# 73266     True
# 73267    False
# 73268    False
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: bool

# %%
df.loc[filt]
# Out:
#                                                    MainBranch
# ResponseId
# 3           I am not primarily a developer, but I write co...  \
# 7                                 I code primarily as a hobby
# 12          I am not primarily a developer, but I write co...
# 15                             I am a developer by profession
# 17                             I am a developer by profession
# ...                                                       ...
# 73258                                   I am learning to code
# 73262                          I am a developer by profession
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
#
#                                                    Employment
# ResponseId
# 3                                         Employed, full-time  \
# 7                                          Student, part-time
# ...

# %%
df['LanguageHaveWorkedWith'].str[0] == 'J'
# Out:
# ResponseId
# 1        False
# 2         True
# 3        False
# 4        False
# 5        False
#          ...
# 73264    False
# 73265    False
# 73266    False
# 73267    False
# 73268    False
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: bool

# %%
df['LanguageHaveWorkedWith'].str.len() > 10
# Out:
# ResponseId
# 1        False
# 2         True
# 3         True
# 4         True
# 5         True
#          ...
# 73264     True
# 73265     True
# 73266     True
# 73267     True
# 73268     True
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: bool

# %%
df['LanguageHaveWorkedWith'].str.endswith == 'a'

df['LanguageHaveWorkedWith'].str.startswith == 'J'
# Out:
# False
