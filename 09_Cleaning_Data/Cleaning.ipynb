# %%
import pandas as pd

# %%
na_vals = ['NA','Missing']

df = pd.read_csv(r'c:\users\gangu\Desktop\survey_results_public.csv',index_col='Respondent',na_values=na_vals)

schema_df = pd.read_csv(r'c:\users\gangu\Desktop\survey_results_schema.csv',index_col='Column')

# %%
df
# Out:
#                                                    MainBranch Hobbyist
# Respondent
# 1                      I am a student who is learning to code      Yes  \
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer
# Respondent
# ...

# %%
df.head(10)
# Out:
#                                                    MainBranch Hobbyist
# Respondent
# 1                      I am a student who is learning to code      Yes  \
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
#
#                            OpenSourcer
# Respondent
# 1                                Never  \
# 2              Less than once per year
# ...

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)

df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
df['YearsCode'].dtype
# Out:
# dtype('O')

# %%
df['YearsCode'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\gangu\source\repos\Pandas\9_Cleaning_Data\Cleaning.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gangu/source/repos/Pandas/9_Cleaning_Data/Cleaning.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> df['YearsCode'].mean()
#
# File c:\Users\gangu\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11563, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11546 @doc(
#   11547     _num_doc,
#   11548     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11561     **kwargs,
#   11562 ):
# > 11563     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# ...

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].dtype
# Out:
# dtype('float64')

# %%
df['YearsCode'].mean()
# Out:
# 11.589040005458392

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %%
df['YearsCode'].mode()
# Out:
# 0    5.0
# Name: YearsCode, dtype: float64
